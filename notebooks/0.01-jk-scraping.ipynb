# %%
import numpy as np
import pickle
import requests
import time

# %% [markdown]
# ## Grab `tournament info`
# Date, location, divisions, courses

# %%
# HTML headers to amicably communicate with the PDGA servers
headers = {'value': 'application/json, text/javascript, */*; q=0.01','accept': 'application/json, text/javascript, */*; q=0.01','cookie': 'cookie-agreed-version=1.0.1; clientSettings=%7B%22favoritePlayers%22%3A%5B%5D%2C%22showFavorites%22%3Atrue%2C%22metric%22%3Afalse%2C%22colorAccessibility%22%3Afalse%2C%22darkMode%22%3Atrue%2C%22throwTracker%22%3Atrue%2C%22userTimeZoneEnabled%22%3Atrue%7D'}

# %%
tournament_id = 89132
url = 'https://www.pdga.com/apps/tournament/live-api/live_results_fetch_event?TournID='

page = requests.get(url + str(tournament_id), headers=headers)

tournament_info = page.json()['data']

# %%
tournament_info
# Out:
# {'DateRange': 'Aug 9-10, 2025',
#  'EndDate': '2025-08-10',
#  'Country': 'United States',
#  'Location': 'Perkasie, Pennsylvania',
#  'LocationShort': 'Perkasie, PA',
#  'Divisions': [{'DivisionID': 100,
#    'Division': 'MPO',
#    'DivisionName': 'Mixed Pro Open',
#    'Players': 71,
#    'IsPro': True,
#    'ShortName': 'Mixed Pro Open',
#    'AbbreviatedName': 'Mixed Pro Open',
#    'LatestRound': 2},
#   {'DivisionID': 105,
#    'Division': 'FPO',
#    'DivisionName': "Women's Pro Open",
#    'Players': 14,
#    'IsPro': True,
#    'ShortName': "Women's Pro Open",
#    'AbbreviatedName': "Women's Pro Open",
#    'LatestRound': 2},
#   {'DivisionID': 111,
#    'Division': 'MP40',
#    'DivisionName': 'Mixed Pro 40+',
#    'Players': 21,
#    'IsPro': True,
#    'ShortName': 'Mixed Pro 40+',
#    'AbbreviatedName': 'Mixed Pro 40+',
#    'LatestRound': 2},
#   {'DivisionID': 400,
#    'Division': 'MA1',
#    'DivisionName': 'Mixed Amateur 1',
#    'Players': 38,
#    'IsPro': False,
#    'ShortName': 'Mixed Amateur 1',
#    'AbbreviatedName': 'Mixed Am 1',
#    'LatestRound': 2},
#   {'DivisionID': 411,
#    'Division': 'MA40',
#    'DivisionName': 'Mixed Amateur 40+',
#    'Players': 4,
#    'IsPro': False,
#    'ShortName': 'Mixed Amateur 40+',
#    'AbbreviatedName': 'Mixed Am 40+',
#    'LatestRound': 2},
#   {'DivisionID': 500,
#    'Division': 'MA2',
#    'DivisionName': 'Mixed Amateur 2',
#    'Players': 25,
#    'IsPro': False,
#    'ShortName': 'Mixed Amateur 2',
#    'AbbreviatedName': 'Mixed Am 2',
#    'LatestRound': 2},
#   {'DivisionID': 600,
#    'Division': 'MA3',
#    'DivisionName': 'Mixed Amateur 3',
#    'Players': 7,
#    'IsPro': False,
#    'ShortName': 'Mixed Amateur 3',
#    'AbbreviatedName': 'Mixed Am 3',
#    'LatestRound': 2}],
#  'Finals': 'no',
#  'HighestCompletedRound': 2,
#  'LatestRound': 2,
#  'FinalRound': 2,
#  'Layouts': [{'LayoutID': 700303,
#    'CourseID': 25812,
#    'CourseName': 'Nockamixon State Park',
#    'Name': 'LVO 2025',
#    'Holes': 18,
#    'Par': 68,
#    'Length': 9325,
#    'Units': 'Feet',
#    'Accuracy': 'M',
#    'Details': [{'Hole': 'H1', 'Label': '1', 'Par': 5, 'Length': 845},
#     {'Hole': 'H2', 'Label': '2', 'Par': 4, 'Length': 483},
#     {'Hole': 'H3', 'Label': '3', 'Par': 3, 'Length': 220},
#     {'Hole': 'H4', 'Label': '4', 'Par': 4, 'Length': 644},
#     {'Hole': 'H5', 'Label': '5', 'Par': 3, 'Length': 304},
#     {'Hole': 'H6', 'Label': '6', 'Par': 4, 'Length': 626},
#     {'Hole': 'H7', 'Label': '7', 'Par': 3, 'Length': 390},
#     {'Hole': 'H8', 'Label': '8', 'Par': 4, 'Length': 570},
#     {'Hole': 'H9', 'Label': '9', 'Par': 4, 'Length': 541},
#     {'Hole': 'H10', 'Label': '10', 'Par': 4, 'Length': 565},
#     {'Hole': 'H11', 'Label': '11', 'Par': 4, 'Length': 404},
#     {'Hole': 'H12', 'Label': '12', 'Par': 3, 'Length': 317},
#     {'Hole': 'H13', 'Label': '13', 'Par': 4, 'Length': 617},
#     {'Hole': 'H14', 'Label': '14', 'Par': 5, 'Length': 769},
#     {'Hole': 'H15', 'Label': '15', 'Par': 3, 'Length': 358},
#     {'Hole': 'H16', 'Label': '16', 'Par': 3, 'Length': 377},
#     {'Hole': 'H17', 'Label': '17', 'Par': 4, 'Length': 542},
#     {'Hole': 'H18', 'Label': '18', 'Par': 4, 'Length': 753}]},
#   {'LayoutID': 700560,
#    'CourseID': 240376,
#    'CourseName': 'The Preserve',
#    'Name': 'LVO 2025 ',
#    'Holes': 18,
#    'Par': 63,
#    'Length': 9073,
#    'Units': 'Feet',
#    'Accuracy': 'M',
#    'Details': [{'Hole': 'H1', 'Label': '1', 'Par': 3, 'Length': 381},
#     {'Hole': 'H2', 'Label': '2', 'Par': 3, 'Length': 449},
#     {'Hole': 'H3', 'Label': '3', 'Par': 3, 'Length': 325},
#     {'Hole': 'H4', 'Label': '4', 'Par': 3, 'Length': 320},
#     {'Hole': 'H5', 'Label': '5', 'Par': 4, 'Length': 620},
#     {'Hole': 'H6', 'Label': '6', 'Par': 4, 'Length': 422},
#     {'Hole': 'H7', 'Label': '7', 'Par': 3, 'Length': 370},
#     {'Hole': 'H8', 'Label': '8', 'Par': 4, 'Length': 649},
#     {'Hole': 'H9', 'Label': '9', 'Par': 3, 'Length': 420},
#     {'Hole': 'H10', 'Label': '10', 'Par': 4, 'Length': 538},
#     {'Hole': 'H11', 'Label': '11', 'Par': 3, 'Length': 390},
#     {'Hole': 'H12', 'Label': '12', 'Par': 3, 'Length': 285},
#     {'Hole': 'H13', 'Label': '13', 'Par': 4, 'Length': 831},
#     {'Hole': 'H14', 'Label': '14', 'Par': 4, 'Length': 589},
#     {'Hole': 'H15', 'Label': '15', 'Par': 4, 'Length': 665},
#     {'Hole': 'H16', 'Label': '16', 'Par': 4, 'Length': 617},
#     {'Hole': 'H17', 'Label': '17', 'Par': 3, 'Length': 402},
#     {'Hole': 'H18', 'Label': '18', 'Par': 4, 'Length': 800}]},
#   {'LayoutID': 724805,
#    'CourseID': 240376,
#    'CourseName': 'The Preserve',
#    'Name': 'LVO 2025 FPO',
#    'Holes': 18,
#    'Par': 67,
#    'Length': 8188,
#    'Units': 'Feet',
#    'Accuracy': 'M',
#    'Details': [{'Hole': 'H1', 'Label': '1', 'Par': 3, 'Length': 381},
#     {'Hole': 'H2', 'Label': '2', 'Par': 3, 'Length': 343},
#     {'Hole': 'H3', 'Label': '3', 'Par': 3, 'Length': 325},
#     {'Hole': 'H4', 'Label': '4', 'Par': 3, 'Length': 320},
#     {'Hole': 'H5', 'Label': '5', 'Par': 4, 'Length': 497},
#     {'Hole': 'H6', 'Label': '6', 'Par': 4, 'Length': 422},
#     {'Hole': 'H7', 'Label': '7', 'Par': 3, 'Length': 270},
#     {'Hole': 'H8', 'Label': '8', 'Par': 5, 'Length': 645},
#     {'Hole': 'H9', 'Label': '9', 'Par': 4, 'Length': 496},
#     {'Hole': 'H10', 'Label': '10', 'Par': 5, 'Length': 538},
#     {'Hole': 'H11', 'Label': '11', 'Par': 3, 'Length': 250},
#     {'Hole': 'H12', 'Label': '12', 'Par': 3, 'Length': 285},
#     {'Hole': 'H13', 'Label': '13', 'Par': 5, 'Length': 831},
#     {'Hole': 'H14', 'Label': '14', 'Par': 3, 'Length': 290},
#     {'Hole': 'H15', 'Label': '15', 'Par': 4, 'Length': 475},
#     {'Hole': 'H16', 'Label': '16', 'Par': 4, 'Length': 618},
#     {'Hole': 'H17', 'Label': '17', 'Par': 3, 'Length': 400},
#     {'Hole': 'H18', 'Label': '18', 'Par': 5, 'Length': 802}]}],
#  'Name': 'The Lost Valley Open Presented by MVP Discs and OTB East',
#  'NameHtml': 'The Lost Valley Open Presented by MVP Discs and OTB East',
#  'MultiLineName': {'pre': '',
#   'main': 'The Lost Valley Open',
#   'post': 'Presented by MVP Discs and OTB East'},
#  'MultiLineNameHtml': ' <span class="event-name-main">The Lost Valley Open</span> <span class="event-name-post">Presented by MVP Discs and OTB East</span>',
#  'RawTier': 'B',
#  'Rounds': 2,
#  'RoundsList': {'1': {'Number': 1,
#    'Label': 'Round 1',
#    'LabelAbbreviated': 'Rd 1',
#    'Date': '2025-08-10',
#    'DateAbbreviated': 'Aug 10',
#    'ShowDate': False},
#   '2': {'Number': 2,
#    'Label': 'Round 2',
#    'LabelAbbreviated': 'Rd 2',
#    'Date': '2025-08-10',
#    'DateAbbreviated': 'Aug 10',
#    'ShowDate': False}},
#  'Semis': 'no',
#  'SimpleName': 'The Lost Valley Open',
#  'StartDate': '2025-08-09',
#  'TDName': 'Steve Braud',
#  'TDPDGANum': 16027,
#  'Tier': 'B',
#  'FormattedTier': 'B-Tier',
#  'FormattedLongTier': 'B-Tier',
#  'TierPro': 'B',
#  'TierAm': 'B',
#  'TierX': False,
#  'TotalPlayers': 180,
#  'TournamentId': '89132',
#  'International': False,
#  'FullStats': True,
#  'TimeZone': None,
#  'AdditionalEventInfo': None,
#  'EventVideo': None,
#  'ScoringFormat': 'S'}

# %% [markdown]
# ## Extract divisions from `tournament_info`
# Will use subsequently to create player lists for each division

# %%
divisions = []
for div in tournament_info['Divisions']:
    divisions.append(div['Division'])

# %%
print(divisions)
# Out:
# ['MPO', 'FPO', 'MP40', 'MA1', 'MA40', 'MA2', 'MA3']

# %% [markdown]
# ## Grab `live_layout`

# %%
url = 'https://www.pdga.com/api/v1/live-tournaments/89132/live-layouts?include=LiveLayoutDetails'
live_layout = requests.get(url, headers=headers).json()

live_layout
# Out:
# [{'layoutId': 700303,
#   'courseId': 25812,
#   'courseName': 'Nockamixon State Park',
#   'tournId': 89132,
#   'name': 'LVO 2025',
#   'holes': 18,
#   'par': 68,
#   'length': 9325,
#   'units': 'Feet',
#   'accuracy': 'M',
#   'notes': '',
#   'ssaRd1': 65.892,
#   'ssaRd2': 64.391,
#   'ssaRd3': None,
#   'ssaRd4': None,
#   'ssaRd5': None,
#   'ssaRd6': None,
#   'ssaRd7': None,
#   'ssaRd8': None,
#   'ssaRd9': None,
#   'ssaRd10': None,
#   'ssaSemis': None,
#   'ssaFinals': None,
#   'combinedSSA': None,
#   'provisionalSSA': None,
#   'challengeFactor': None,
#   'updateDate': '2025-08-18T17:18:02+00:00',
#   'liveLayoutDetails': [{'layoutDetailId': 18579574,
#     'layoutId': 700303,
#     'hole': 'H1',
#     'holeOrdinal': 1,
#     'label': '1',
#     'tee': None,
#     'target': None,
#     'par': 5,
#     'length': 845,
#     'notes': 'Creek around green plays as river',
#     'updateDate': '2025-08-06T14:01:06+00:00'},
#    {'layoutDetailId': 18579575,
#     'layoutId': 700303,
#     'hole': 'H2',
#     'holeOrdinal': 2,
#     'label': '2',
#     'tee': None,
#     'target': None,
#     'par': 4,
#     'length': 483,
#     'notes': 'Water behind basket is OB. the creek before the basket plays as a river.',
#     'updateDate': '2025-08-06T14:01:06+00:00'},
#    {'layoutDetailId': 18579576,
#     'layoutId': 700303,
#     'hole': 'H3',
#     'holeOrdinal': 3,
#     'label': '3',
#     'tee': None,
#     'target': None,
#     'par': 3,
#     'length': 220,
#     'notes': 'Creek OB',
#     'updateDate': '2025-08-06T14:01:06+00:00'},
#    {'layoutDetailId': 18579577,
#     'layoutId': 700303,
#     'hole': 'H4',
#     'holeOrdinal': 4,
#     'label': '4',
#     'tee': None,
#     'target': None,
#     'par': 4,
#     'length': 644,
#     'notes': 'Creek OB',
#     'updateDate': '2025-08-06T14:01:06+00:00'},
#    {'layoutDetailId': 18579578,
#     'layoutId': 700303,
#     'hole': 'H5',
#     'holeOrdinal': 5,
#     'label': '5',
#     'tee': None,
#     'target': None,
#     'par': 3,
#     'length': 304,
#     'notes': 'Creek OB',
#     'updateDate': '2025-08-06T14:01:06+00:00'},
#    {'layoutDetailId': 18579579,
#     'layoutId': 700303,
#     'hole': 'H6',
#     'holeOrdinal': 6,
#     'label': '6',
#     'tee': None,
#     'target': None,
#     'par': 4,
#     'length': 626,
#     'notes': 'Road & across',
#     'updateDate': '2025-08-06T14:01:06+00:00'},
#    {'layoutDetailId': 18579580,
#     'layoutId': 700303,
#     'hole': 'H7',
#     'holeOrdinal': 7,
#     'label': '7',
#     'tee': None,
#     'target': None,
#     'par': 3,
#     'length': 390,
#     'notes': 'Creek before and behind basket plays as a river. If OB in first creek or in tunnel use drop zone marked with white flags',
#     'updateDate': '2025-08-09T00:39:31+00:00'},
#    {'layoutDetailId': 18579581,
#     'layoutId': 700303,
#     'hole': 'H8',
#     'holeOrdinal': 8,
#     'label': '8',
#     'tee': None,
#     'target': None,
#     'par': 4,
#     'length': 570,
#     'notes': 'Swamp to the left, rope and beyond behind the basket are OB. All lost discs off the tee will proceed to the flagged drop zone with a 1 stroke penalty. All other lost discs will be played from previous lie with a 1 stroke penalty. SPOTTER RECOMMENDED',
#     'updateDate': '2025-08-06T14:01:06+00:00'},
#    {'layoutDetailId': 18579582,
#     'layoutId': 700303,
#     'hole': 'H9',
#     'holeOrdinal': 9,
#     'label': '9',
#     'tee': None,
#     'target': None,
#     'par': 4,
#     'length': 541,
#     'notes': 'Pond OB',
#     'updateDate': '2025-08-06T14:01:06+00:00'},
#    {'layoutDetailId': 18579583,
#     'layoutId': 700303,
#     'hole': 'H10',
#     'holeOrdinal': 10,
#     'label': '10',
#     'tee': None,
#     'target': None,
#     'par': 4,
#     'length': 565,
#     'notes': 'Pond OB',
#     'updateDate': '2025-08-06T14:01:06+00:00'},
#    {'layoutDetailId': 18579584,
#     'layoutId': 700303,
#     'hole': 'H11',
#     'holeOrdinal': 11,
#     'label': '11',
#     'tee': None,
#     'target': None,
#     'par': 4,
#     'length': 404,
#     'notes': 'Flagged Concrete pad in front of basket, road and across behind basket are OB. Disreguard the steaks & roped off area (this area palys as in bounds)',
#     'updateDate': '2025-08-09T00:39:31+00:00'},
#    {'layoutDetailId': 18579585,
#     'layoutId': 700303,
#     'hole': 'H12',
#     'holeOrdinal': 12,
#     'label': '12',
#     'tee': None,
#     'target': None,
#     'par': 3,
#     'length': 317,
#     'notes': 'Road and across',
#     'updateDate': '2025-08-06T14:01:06+00:00'},
#    {'layoutDetailId': 18579586,
#     'layoutId': 700303,
#     'hole': 'H13',
#     'holeOrdinal': 13,
#     'label': '13',
#     'tee': None,
#     'target': None,
#     'par': 4,
#     'length': 617,
#     'notes': 'Road and across',
#     'updateDate': '2025-08-06T14:01:06+00:00'},
#    {'layoutDetailId': 18579587,
#     'layoutId': 700303,
#     'hole': 'H14',
#     'holeOrdinal': 14,
#     'label': '14',
#     'tee': None,
#     'target': None,
#     'par': 5,
#     'length': 769,
#     'notes': 'Road and across, white stakes and beyond to the left of fairway are OB',
#     'updateDate': '2025-08-06T14:01:06+00:00'},
#    {'layoutDetailId': 18579588,
#     'layoutId': 700303,
#     'hole': 'H15',
#     'holeOrdinal': 15,
#     'label': '15',
#     'tee': None,
#     'target': None,
#     'par': 3,
#     'length': 358,
#     'notes': 'Road and across',
#     'updateDate': '2025-08-06T14:01:06+00:00'},
#    {'layoutDetailId': 18579589,
#     'layoutId': 700303,
#     'hole': 'H16',
#     'holeOrdinal': 16,
#     'label': '16',
#     'tee': None,
#     'target': None,
#     'par': 3,
#     'length': 377,
#     'notes': 'Road and across',
#     'updateDate': '2025-08-06T14:01:06+00:00'},
#    {'layoutDetailId': 18579590,
#     'layoutId': 700303,
#     'hole': 'H17',
#     'holeOrdinal': 17,
#     'label': '17',
#     'tee': None,
#     'target': None,
#     'par': 4,
#     'length': 542,
#     'notes': 'Road and across',
#     'updateDate': '2025-08-06T14:01:06+00:00'},
#    {'layoutDetailId': 18579591,
#     'layoutId': 700303,
#     'hole': 'H18',
#     'holeOrdinal': 18,
#     'label': '18',
#     'tee': None,
#     'target': None,
#     'par': 4,
#     'length': 753,
#     'notes': 'Road and across',
#     'updateDate': '2025-08-06T14:01:06+00:00'}]},
#  {'layoutId': 700560,
#   'courseId': 240376,
#   'courseName': 'The Preserve Disc Golf Course',
#   'tournId': 89132,
#   'name': 'LVO 2025 ',
#   'holes': 18,
#   'par': 63,
#   'length': 9073,
#   'units': 'Feet',
#   'accuracy': 'M',
#   'notes': '',
#   'ssaRd1': 63.168,
#   'ssaRd2': 63.221,
#   'ssaRd3': None,
#   'ssaRd4': None,
#   'ssaRd5': None,
#   'ssaRd6': None,
#   'ssaRd7': None,
#   'ssaRd8': None,
#   'ssaRd9': None,
#   'ssaRd10': None,
#   'ssaSemis': None,
#   'ssaFinals': None,
#   'combinedSSA': None,
#   'provisionalSSA': None,
#   'challengeFactor': None,
#   'updateDate': '2025-08-18T17:18:02+00:00',
#   'liveLayoutDetails': [{'layoutDetailId': 18589641,
#     'layoutId': 700560,
#     'hole': 'H1',
#     'holeOrdinal': 1,
#     'label': '1',
#     'tee': 'main',
#     'target': 'blue',
#     'par': 3,
#     'length': 381,
#     'notes': 'Field on the right side and ponds are OB. Use drop zone off tee shot only, play where last in bounds on all other throws.',
#     'updateDate': '2025-08-06T14:19:24+00:00'},
#    {'layoutDetailId': 18589642,
#     'layoutId': 700560,
#     'hole': 'H2',
#     'holeOrdinal': 2,
#     'label': '2',
#     'tee': 'main',
#     'target': 'blue',
#     'par': 3,
#     'length': 449,
#     'notes': None,
#     'updateDate': '2025-08-06T14:23:40+00:00'},
#    {'layoutDetailId': 18589643,
#     'layoutId': 700560,
#     'hole': 'H3',
#     'holeOrdinal': 3,
#     'label': '3',
#     'tee': 'main',
#     'target': 'blue',
#     'par': 3,
#     'length': 325,
#     'notes': 'Field on right OB',
#     'updateDate': '2025-08-06T14:19:24+00:00'},
#    {'layoutDetailId': 18589644,
#     'layoutId': 700560,
#     'hole': 'H4',
#     'holeOrdinal': 4,
#     'label': '4',
#     'tee': 'main',
#     'target': 'blue',
#     'par': 3,
#     'length': 320,
#     'notes': 'Fields on left, right, and long of basket OB',
#     'updateDate': '2025-08-06T14:19:24+00:00'},
#    {'layoutDetailId': 18589645,
#     'layoutId': 700560,
#     'hole': 'H5',
#     'holeOrdinal': 5,
#     'label': '5',
#     'tee': 'main',
#     'target': 'blue',
#     'par': 4,
#     'length': 620,
#     'notes': 'Field on left OB',
#     'updateDate': '2025-08-06T14:23:40+00:00'},
#    {'layoutDetailId': 18589646,
#     'layoutId': 700560,
#     'hole': 'H6',
#     'holeOrdinal': 6,
#     'label': '6',
#     'tee': 'main',
#     'target': 'blue',
#     'par': 4,
#     'length': 422,
#     'notes': 'Stakes/line on right side of the far ditch and long of basket OB',
#     'updateDate': '2025-08-06T14:19:24+00:00'},
#    {'layoutDetailId': 18589647,
#     'layoutId': 700560,
#     'hole': 'H7',
#     'holeOrdinal': 7,
#     'label': '7',
#     'tee': 'main',
#     'target': 'blue',
#     'par': 3,
#     'length': 370,
#     'notes': None,
#     'updateDate': '2025-08-06T14:23:40+00:00'},
#    {'layoutDetailId': 18589648,
#     'layoutId': 700560,
#     'hole': 'H8',
#     'holeOrdinal': 8,
#     'label': '8',
#     'tee': 'main',
#     'target': 'blue',
#     'par': 4,
#     'length': 649,
#     'notes': 'Right side of field OB',
#     'updateDate': '2025-08-06T14:23:40+00:00'},
#    {'layoutDetailId': 18589649,
#     'layoutId': 700560,
#     'hole': 'H9',
#     'holeOrdinal': 9,
#     'label': '9',
#     'tee': 'main',
#     'target': 'blue',
#     'par': 3,
#     'length': 420,
#     'notes': None,
#     'updateDate': '2025-08-06T14:23:40+00:00'},
#    {'layoutDetailId': 18589650,
#     'layoutId': 700560,
#     'hole': 'H10',
#     'holeOrdinal': 10,
#     'label': '10',
#     'tee': 'main',
#     'target': 'blue',
#     'par': 4,
#     'length': 538,
#     'notes': 'Field on left, right, and surrounding green OB',
#     'updateDate': '2025-08-06T14:23:40+00:00'},
#    {'layoutDetailId': 18589651,
#     'layoutId': 700560,
#     'hole': 'H11',
#     'holeOrdinal': 11,
#     'label': '11',
#     'tee': 'main',
#     'target': 'blue',
#     'par': 3,
#     'length': 390,
#     'notes': None,
#     'updateDate': '2025-08-06T14:23:40+00:00'},
#    {'layoutDetailId': 18589652,
#     'layoutId': 700560,
#     'hole': 'H12',
#     'holeOrdinal': 12,
#     'label': '12',
#     'tee': 'main',
#     'target': 'blue',
#     'par': 3,
#     'length': 285,
#     'notes': 'NONE - stakes on right are for hole 10 ',
#     'updateDate': '2025-08-06T14:19:24+00:00'},
#    {'layoutDetailId': 18589653,
#     'layoutId': 700560,
#     'hole': 'H13',
#     'holeOrdinal': 13,
#     'label': '13',
#     'tee': 'main',
#     'target': 'blue',
#     'par': 4,
#     'length': 831,
#     'notes': 'Gravel road (on left) and Runway (on right) are OB on & across. Line long of straight fairway is also OB. Island green.',
#     'updateDate': '2025-08-06T14:23:40+00:00'},
#    {'layoutDetailId': 18589654,
#     'layoutId': 700560,
#     'hole': 'H14',
#     'holeOrdinal': 14,
#     'label': '14',
#     'tee': 'main',
#     'target': 'blue',
#     'par': 4,
#     'length': 589,
#     'notes': 'Foliage along left side and crop field long OB',
#     'updateDate': '2025-08-06T14:23:40+00:00'},
#    {'layoutDetailId': 18589655,
#     'layoutId': 700560,
#     'hole': 'H15',
#     'holeOrdinal': 15,
#     'label': '15',
#     'tee': 'new long turf',
#     'target': 'blue',
#     'par': 4,
#     'length': 665,
#     'notes': 'Field on left, foliage on right, and field long of basket OB',
#     'updateDate': '2025-08-06T14:23:40+00:00'},
#    {'layoutDetailId': 18589656,
#     'layoutId': 700560,
#     'hole': 'H16',
#     'holeOrdinal': 16,
#     'label': '16',
#     'tee': 'main',
#     'target': 'blue',
#     'par': 4,
#     'length': 617,
#     'notes': 'Fields on left, right, and long of basket OB',
#     'updateDate': '2025-08-06T14:23:40+00:00'},
#    {'layoutDetailId': 18589657,
#     'layoutId': 700560,
#     'hole': 'H17',
#     'holeOrdinal': 17,
#     'label': '17',
#     'tee': 'main',
#     'target': 'blue',
#     'par': 3,
#     'length': 402,
#     'notes': 'Field on far left',
#     'updateDate': '2025-08-06T14:23:40+00:00'},
#    {'layoutDetailId': 18589658,
#     'layoutId': 700560,
#     'hole': 'H18',
#     'holeOrdinal': 18,
#     'label': '18',
#     'tee': 'main',
#     'target': 'blue',
#     'par': 4,
#     'length': 800,
#     'notes': 'Tree line/corn field on the right (starting down the fairway), gravel road and across OB',
#     'updateDate': '2025-08-06T14:23:40+00:00'}]},
#  {'layoutId': 724805,
#   'courseId': 240376,
#   'courseName': 'The Preserve Disc Golf Course',
#   'tournId': 89132,
#   'name': 'LVO 2025 FPO',
#   'holes': 18,
#   'par': 67,
#   'length': 8188,
#   'units': 'Feet',
#   'accuracy': 'M',
#   'notes': '',
#   'ssaRd1': None,
#   'ssaRd2': 58.907,
#   'ssaRd3': None,
#   'ssaRd4': None,
#   'ssaRd5': None,
#   'ssaRd6': None,
#   'ssaRd7': None,
#   'ssaRd8': None,
#   'ssaRd9': None,
#   'ssaRd10': None,
#   'ssaSemis': None,
#   'ssaFinals': None,
#   'combinedSSA': None,
#   'provisionalSSA': None,
#   'challengeFactor': None,
#   'updateDate': '2025-08-18T17:18:02+00:00',
#   'liveLayoutDetails': [{'layoutDetailId': 19801597,
#     'layoutId': 724805,
#     'hole': 'H1',
#     'holeOrdinal': 1,
#     'label': '1',
#     'tee': 'main',
#     'target': 'blue',
#     'par': 3,
#     'length': 381,
#     'notes': 'Field on the right side and ponds are OB. Use drop zone off tee shot only, play where last in bounds on all other throws.',
#     'updateDate': '2025-08-06T14:19:24+00:00'},
#    {'layoutDetailId': 19801598,
#     'layoutId': 724805,
#     'hole': 'H2',
#     'holeOrdinal': 2,
#     'label': '2',
#     'tee': 'main',
#     'target': 'yellow',
#     'par': 3,
#     'length': 343,
#     'notes': None,
#     'updateDate': '2025-08-06T14:27:54+00:00'},
#    {'layoutDetailId': 19801599,
#     'layoutId': 724805,
#     'hole': 'H3',
#     'holeOrdinal': 3,
#     'label': '3',
#     'tee': 'main',
#     'target': 'blue',
#     'par': 3,
#     'length': 325,
#     'notes': 'Field on right OB',
#     'updateDate': '2025-08-06T14:19:24+00:00'},
#    {'layoutDetailId': 19801600,
#     'layoutId': 724805,
#     'hole': 'H4',
#     'holeOrdinal': 4,
#     'label': '4',
#     'tee': 'main',
#     'target': 'blue',
#     'par': 3,
#     'length': 320,
#     'notes': 'Fields on left, right, and long of basket OB',
#     'updateDate': '2025-08-06T14:19:24+00:00'},
#    {'layoutDetailId': 19801601,
#     'layoutId': 724805,
#     'hole': 'H5',
#     'holeOrdinal': 5,
#     'label': '5',
#     'tee': 'turf on bridge',
#     'target': 'blue',
#     'par': 4,
#     'length': 497,
#     'notes': 'Field on left OB',
#     'updateDate': '2025-08-06T14:27:54+00:00'},
#    {'layoutDetailId': 19801602,
#     'layoutId': 724805,
#     'hole': 'H6',
#     'holeOrdinal': 6,
#     'label': '6',
#     'tee': 'main',
#     'target': 'blue',
#     'par': 4,
#     'length': 422,
#     'notes': 'Stakes/line on right side of the far ditch and long of basket OB',
#     'updateDate': '2025-08-06T14:19:24+00:00'},
#    {'layoutDetailId': 19801603,
#     'layoutId': 724805,
#     'hole': 'H7',
#     'holeOrdinal': 7,
#     'label': '7',
#     'tee': 'short turf',
#     'target': 'blue',
#     'par': 3,
#     'length': 270,
#     'notes': None,
#     'updateDate': '2025-08-06T14:27:54+00:00'},
#    {'layoutDetailId': 19801604,
#     'layoutId': 724805,
#     'hole': 'H8',
#     'holeOrdinal': 8,
#     'label': '8',
#     'tee': 'main',
#     'target': 'blue',
#     'par': 5,
#     'length': 645,
#     'notes': 'Right side of field OB',
#     'updateDate': '2025-08-06T14:27:54+00:00'},
#    {'layoutDetailId': 19801605,
#     'layoutId': 724805,
#     'hole': 'H9',
#     'holeOrdinal': 9,
#     'label': '9',
#     'tee': 'main',
#     'target': 'white',
#     'par': 4,
#     'length': 496,
#     'notes': None,
#     'updateDate': '2025-08-06T14:27:54+00:00'},
#    {'layoutDetailId': 19801606,
#     'layoutId': 724805,
#     'hole': 'H10',
#     'holeOrdinal': 10,
#     'label': '10',
#     'tee': 'main',
#     'target': 'blue',
#     'par': 5,
#     'length': 538,
#     'notes': 'Field on left, right, and surrounding green OB',
#     'updateDate': '2025-08-06T14:27:54+00:00'},
#    {'layoutDetailId': 19801607,
#     'layoutId': 724805,
#     'hole': 'H11',
#     'holeOrdinal': 11,
#     'label': '11',
#     'tee': 'main',
#     'target': 'white',
#     'par': 3,
#     'length': 250,
#     'notes': None,
#     'updateDate': '2025-08-06T14:27:54+00:00'},
#    {'layoutDetailId': 19801608,
#     'layoutId': 724805,
#     'hole': 'H12',
#     'holeOrdinal': 12,
#     'label': '12',
#     'tee': 'main',
#     'target': 'blue',
#     'par': 3,
#     'length': 285,
#     'notes': 'NONE - stakes on right are for hole 10 ',
#     'updateDate': '2025-08-06T14:19:24+00:00'},
#    {'layoutDetailId': 19801609,
#     'layoutId': 724805,
#     'hole': 'H13',
#     'holeOrdinal': 13,
#     'label': '13',
#     'tee': 'main',
#     'target': 'blue',
#     'par': 5,
#     'length': 831,
#     'notes': 'Gravel road (on left) and Runway (on right) are OB on & across. Line long of straight fairway is also OB. Island green.',
#     'updateDate': '2025-08-06T14:27:54+00:00'},
#    {'layoutDetailId': 19801610,
#     'layoutId': 724805,
#     'hole': 'H14',
#     'holeOrdinal': 14,
#     'label': '14',
#     'tee': 'main',
#     'target': 'yellow',
#     'par': 3,
#     'length': 290,
#     'notes': 'Foliage along left side and crop field long OB',
#     'updateDate': '2025-08-06T14:27:54+00:00'},
#    {'layoutDetailId': 19801611,
#     'layoutId': 724805,
#     'hole': 'H15',
#     'holeOrdinal': 15,
#     'label': '15',
#     'tee': 'short turf',
#     'target': 'yellow',
#     'par': 4,
#     'length': 475,
#     'notes': 'Field on left, foliage on right, and field long of basket OB',
#     'updateDate': '2025-08-06T14:27:54+00:00'},
#    {'layoutDetailId': 19801612,
#     'layoutId': 724805,
#     'hole': 'H16',
#     'holeOrdinal': 16,
#     'label': '16',
#     'tee': 'main',
#     'target': 'blue',
#     'par': 4,
#     'length': 618,
#     'notes': 'Fields on left, right, and long of basket OB',
#     'updateDate': '2025-08-06T14:27:54+00:00'},
#    {'layoutDetailId': 19801613,
#     'layoutId': 724805,
#     'hole': 'H17',
#     'holeOrdinal': 17,
#     'label': '17',
#     'tee': 'main',
#     'target': 'blue',
#     'par': 3,
#     'length': 400,
#     'notes': 'Field on far left',
#     'updateDate': '2025-08-06T14:27:54+00:00'},
#    {'layoutDetailId': 19801614,
#     'layoutId': 724805,
#     'hole': 'H18',
#     'holeOrdinal': 18,
#     'label': '18',
#     'tee': 'main',
#     'target': 'blue',
#     'par': 5,
#     'length': 802,
#     'notes': 'Tree line/corn field on the right (starting down the fairway), gravel road and across OB',
#     'updateDate': '2025-08-06T14:27:54+00:00'}]}]

# %% [markdown]
# ## Create list of `ResultID`'s
# A player performance for the entire tournament is denoted by a `ResultID`.

# %%
# Create list of ResultID's
result_ids = []
baseurl = 'https://www.pdga.com/apps/tournament/live-api/live_results_fetch_updated_round_scores?TournID=89132&Division='

for div in divisions:
    url = baseurl + div
    page = requests.get(url, headers=headers)
    data = page.json()["data"]

    for d in data:
        result_ids.append(d['ResultID'])

print(result_ids)
# Out:
# [211586222, 211586679, 211653303, 211863789, 211586118, 211586517, 211633208, 211586319, 211586525, 211589754, 211940397, 211899475, 211878383, 211925757, 211587409, 212019900, 212018592, 211876645, 211792604, 211703637, 211898508, 211740116, 211586594, 211618411, 211899449, 211638413, 211587325, 212013095, 212008899, 211581461, 211581674, 212018626, 211951751, 211887814, 211588238, 211593542, 211948809, 211586579, 211949799, 211806823, 211586057, 211611952, 211688052, 211897410, 211688048, 211883536, 211916920, 212015146, 211587267, 211881568, 211757332, 211965179, 211589937, 211617032, 211992741, 211863790, 211951989, 212010853, 211866750, 211612614, 211587416, 211586065, 212025424, 211898980, 211759097, 211899141, 211819520, 212009717, 211744192, 211586584, 211587218, 212013544, 211777194, 212009503, 211706577, 211586629, 211775135, 211589718, 211709048, 211768110, 211651247, 211609878, 211808887, 211783723, 211953374, 211591334, 211752059, 211586986, 211831331, 211786279, 211916926, 212010541, 211947276, 211588228, 211977749, 211596028, 211762131, 211589676, 211610900, 211805705, 211650688, 211840471, 211734321, 211586656, 211625346, 212008923, 211665362, 211993884, 211974212, 211993865, 211929924, 211606720, 211752060, 211642547, 211785361, 211581424, 212016881, 211843489, 212017336, 212016422, 212015339, 212009001, 211662311, 211639570, 212008959, 212013256, 212015373, 211768109, 212013693, 211647078, 212004914, 211586117, 212014935, 211678310, 211586139, 211586461, 211966478, 211904183, 212008158, 212013562, 212015649, 212000573, 212003663, 211983908, 211596298, 212011345, 211623737, 211623013, 211992164, 211950382, 211746412, 211591491, 211941026, 211849806, 211794525, 211980460, 211783741, 211591191, 211894559, 211662002, 211606901, 211947193, 211884966, 211995851, 211927204, 212010140, 211597546, 211966631, 211986528, 211752087, 211982386, 211771209, 211941093, 211728758, 212013365, 212014570, 212014609, 211961653, 211586126, 211929164]

# %% [markdown]
# ## Obtain scoring by fetching data for each `ResultID`

# %%
results = []

baseurl = 'https://www.pdga.com/apps/tournament/live-api/live_results_fetch_player?ResultID='
for i, id in enumerate(result_ids):
    print(f"Grabbing {i} of {len(result_ids)}.")
    page = requests.get(baseurl + str(id))
    data = page.json()['data']

    results.append(data)

    time.sleep(1)  # don't overload server
# Out:
# Grabbing 0 of 180.
# Grabbing 1 of 180.
# Grabbing 2 of 180.
# Grabbing 3 of 180.
# Grabbing 4 of 180.
# Grabbing 5 of 180.
# Grabbing 6 of 180.
# Grabbing 7 of 180.
# Grabbing 8 of 180.
# Grabbing 9 of 180.
# Grabbing 10 of 180.
# Grabbing 11 of 180.
# Grabbing 12 of 180.
# Grabbing 13 of 180.
# Grabbing 14 of 180.
# Grabbing 15 of 180.
# Grabbing 16 of 180.
# Grabbing 17 of 180.
# Grabbing 18 of 180.
# Grabbing 19 of 180.
# Grabbing 20 of 180.
# Grabbing 21 of 180.
# Grabbing 22 of 180.
# Grabbing 23 of 180.
# Grabbing 24 of 180.
# Grabbing 25 of 180.
# Grabbing 26 of 180.
# Grabbing 27 of 180.
# Grabbing 28 of 180.
# Grabbing 29 of 180.
# Grabbing 30 of 180.
# Grabbing 31 of 180.
# Grabbing 32 of 180.
# Grabbing 33 of 180.
# Grabbing 34 of 180.
# Grabbing 35 of 180.
# Grabbing 36 of 180.
# Grabbing 37 of 180.
# Grabbing 38 of 180.
# Grabbing 39 of 180.
# Grabbing 40 of 180.
# Grabbing 41 of 180.
# Grabbing 42 of 180.
# Grabbing 43 of 180.
# Grabbing 44 of 180.
# Grabbing 45 of 180.
# Grabbing 46 of 180.
# Grabbing 47 of 180.
# Grabbing 48 of 180.
# Grabbing 49 of 180.
# Grabbing 50 of 180.
# Grabbing 51 of 180.
# Grabbing 52 of 180.
# Grabbing 53 of 180.
# Grabbing 54 of 180.
# Grabbing 55 of 180.
# Grabbing 56 of 180.
# Grabbing 57 of 180.
# Grabbing 58 of 180.
# Grabbing 59 of 180.
# Grabbing 60 of 180.
# Grabbing 61 of 180.
# Grabbing 62 of 180.
# Grabbing 63 of 180.
# Grabbing 64 of 180.
# Grabbing 65 of 180.
# Grabbing 66 of 180.
# Grabbing 67 of 180.
# Grabbing 68 of 180.
# Grabbing 69 of 180.
# Grabbing 70 of 180.
# Grabbing 71 of 180.
# Grabbing 72 of 180.
# Grabbing 73 of 180.
# Grabbing 74 of 180.
# Grabbing 75 of 180.
# Grabbing 76 of 180.
# Grabbing 77 of 180.
# Grabbing 78 of 180.
# Grabbing 79 of 180.
# Grabbing 80 of 180.
# Grabbing 81 of 180.
# Grabbing 82 of 180.
# Grabbing 83 of 180.
# Grabbing 84 of 180.
# Grabbing 85 of 180.
# Grabbing 86 of 180.
# Grabbing 87 of 180.
# Grabbing 88 of 180.
# Grabbing 89 of 180.
# Grabbing 90 of 180.
# Grabbing 91 of 180.
# Grabbing 92 of 180.
# Grabbing 93 of 180.
# Grabbing 94 of 180.
# Grabbing 95 of 180.
# Grabbing 96 of 180.
# Grabbing 97 of 180.
# Grabbing 98 of 180.
# Grabbing 99 of 180.
# Grabbing 100 of 180.
# Grabbing 101 of 180.
# Grabbing 102 of 180.
# Grabbing 103 of 180.
# Grabbing 104 of 180.
# Grabbing 105 of 180.
# Grabbing 106 of 180.
# Grabbing 107 of 180.
# Grabbing 108 of 180.
# Grabbing 109 of 180.
# Grabbing 110 of 180.
# Grabbing 111 of 180.
# Grabbing 112 of 180.
# Grabbing 113 of 180.
# Grabbing 114 of 180.
# Grabbing 115 of 180.
# Grabbing 116 of 180.
# Grabbing 117 of 180.
# Grabbing 118 of 180.
# Grabbing 119 of 180.
# Grabbing 120 of 180.
# Grabbing 121 of 180.
# Grabbing 122 of 180.
# Grabbing 123 of 180.
# Grabbing 124 of 180.
# Grabbing 125 of 180.
# Grabbing 126 of 180.
# Grabbing 127 of 180.
# Grabbing 128 of 180.
# Grabbing 129 of 180.
# Grabbing 130 of 180.
# Grabbing 131 of 180.
# Grabbing 132 of 180.
# Grabbing 133 of 180.
# Grabbing 134 of 180.
# Grabbing 135 of 180.
# Grabbing 136 of 180.
# Grabbing 137 of 180.
# Grabbing 138 of 180.
# Grabbing 139 of 180.
# Grabbing 140 of 180.
# Grabbing 141 of 180.
# Grabbing 142 of 180.
# Grabbing 143 of 180.
# Grabbing 144 of 180.
# Grabbing 145 of 180.
# Grabbing 146 of 180.
# Grabbing 147 of 180.
# Grabbing 148 of 180.
# Grabbing 149 of 180.
# Grabbing 150 of 180.
# Grabbing 151 of 180.
# Grabbing 152 of 180.
# Grabbing 153 of 180.
# Grabbing 154 of 180.
# Grabbing 155 of 180.
# Grabbing 156 of 180.
# Grabbing 157 of 180.
# Grabbing 158 of 180.
# Grabbing 159 of 180.
# Grabbing 160 of 180.
# Grabbing 161 of 180.
# Grabbing 162 of 180.
# Grabbing 163 of 180.
# Grabbing 164 of 180.
# Grabbing 165 of 180.
# Grabbing 166 of 180.
# Grabbing 167 of 180.
# Grabbing 168 of 180.
# Grabbing 169 of 180.
# Grabbing 170 of 180.
# Grabbing 171 of 180.
# Grabbing 172 of 180.
# Grabbing 173 of 180.
# Grabbing 174 of 180.
# Grabbing 175 of 180.
# Grabbing 176 of 180.
# Grabbing 177 of 180.
# Grabbing 178 of 180.
# Grabbing 179 of 180.

# %% [markdown]
# ## Add information to `data` dictionary

# %%
data = {}

data["tournament_info"] = tournament_info
data["divisions"] = divisions
data["live_layout"] = live_layout
data["result_ids"] = result_ids
data["results"] = results

# %% [markdown]
# ## Save `data` dictionary

# %%
with open(f"../data/raw/{tournament_id}.pkl", 'wb') as f:
    pickle.dump(data, f) # serialize the list
